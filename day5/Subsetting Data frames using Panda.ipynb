# %%
import pandas as pd

stats = pd.read_csv('/home/flippercode/Documents/python-learning/include/best-locations.csv')

# %%
#1 Display the stats
stats
# Out:
#     Unnamed: 0                                     Title  \
# 0          NaN                                Amber Fort
# 1          NaN                           Mehrangarh Fort
# 2          NaN                   National Gallery of Art
# 3          NaN                        Hill Palace Museum
# 4          NaN                              Kirti Mandir
# 5          NaN                      Nehru Science Centre
# 6          NaN                      Raman Science Centre
# 7          NaN                           Red Fort, Delhi
# 8          NaN                             Mysore Palace
# 9          NaN                          Agra Fort, Agra.
# 10         NaN                             Junagadh Fort
# 11         NaN                                   Gulmarg
# 12         NaN                                  Pahalgam
# 13         NaN                                  Sonamarg
# 14         NaN                             Varkala Beach
# ...

# %%
#2 Display stats in Reverse
stats[::-1]
# Out:
#     Unnamed: 0                                     Title  \
# 69         NaN                San Diego State University
# 68         NaN        The University of Texas At El Paso
# 67         NaN                         Auburn University
# 66         NaN  University of Virginia, Charlottesville,
# 65         NaN                        Lincoln University
# 64         NaN                         Lucas Oil Stadium
# 63         NaN                  Texas Woman's University
# 62         NaN                  James Madison University
# 61         NaN                        Paul Brown Stadium
# 60         NaN                        Strawberry Stadium
# 59         NaN                     University of Arizona
# 58         NaN              University of North Carolina
# 57         NaN                  University of Washington
# 56         NaN                   Boise State University,
# 55         NaN             University of Phoenix Stadium
# ...

# %%
#Display Stats only with Row20
stats[::20]
# Out:
#     Unnamed: 0                     Title  \
# 0          NaN                Amber Fort
# 20         NaN             Palolam beach
# 40         NaN  Santa Monica State Beach
# 60         NaN        Strawberry Stadium
#
#                                               Address   Latitude   Longitude  \
# 0          Amber Fort, Amer, Jaipur, Rajasthan, India  26.985487   75.851345
# 20                          Palolem Beach, Goa, India  15.009965   74.023219
# 40  Santa Monica State Beach, Santa Monica, CA, Un...  34.012903 -118.501724
# 60  Strawberry Stadium, Western Avenue, Hammond, L...  30.511026  -90.468579
#
#       City       State        Country Postal Code  \
# 0   Jaipur   Rajasthan          India      302001
# 20     NaN         Goa          India         NaN
# 40     NaN  California  United States       90005
# 60       5   Louisiana  United States       70401
#
#                                               Message       Categories  \
# ...

# %%
#part 2 Coloumns

# %%
stats['Title'].head(5)
# Out:
# 0                 Amber Fort
# 1            Mehrangarh Fort
# 2    National Gallery of Art
# 3         Hill Palace Museum
# 4               Kirti Mandir
# Name: Title, dtype: object

# %%
#You need to pass the list with stats to display multiple columns

stats[['Title','City']].head(10)
# Out:
#                      Title          City
# 0               Amber Fort        Jaipur
# 1          Mehrangarh Fort       Jodhpur
# 2  National Gallery of Art     New Delhi
# 3       Hill Palace Museum  Tripunithura
# 4             Kirti Mandir     Porbandar
# 5     Nehru Science Centre        Mumbai
# 6     Raman Science Centre        Nagpur
# 7          Red Fort, Delhi     New Delhi
# 8            Mysore Palace        Mysuru
# 9         Agra Fort, Agra.          Agra

# %%
#Quickway
stats.Title.head()
# Out:
# 0                 Amber Fort
# 1            Mehrangarh Fort
# 2    National Gallery of Art
# 3         Hill Palace Museum
# 4               Kirti Mandir
# Name: Title, dtype: object

# %%
#Combine the two
stats[5:16] [['Title','City','State','Country']]
# Out:
#                    Title       City              State Country
# 5   Nehru Science Centre     Mumbai        Maharashtra   India
# 6   Raman Science Centre     Nagpur        Maharashtra   India
# 7        Red Fort, Delhi  New Delhi              Delhi   India
# 8          Mysore Palace     Mysuru          Karnataka   India
# 9       Agra Fort, Agra.       Agra      Uttar Pradesh   India
# 10         Junagadh Fort    Bikaner          Rajasthan   India
# 11               Gulmarg  Baramulla  Jammu and Kashmir   India
# 12              Pahalgam   Pahalgam                NaN     NaN
# 13              Sonamarg   Sonamarg                NaN     NaN
# 14         Varkala Beach    Varkala             Kerala   India
# 15                Shimla     Shimla   Himachal Pradesh   India

# %%
stats.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Address', 'Latitude', 'Longitude', 'City',
#        'State', 'Country', 'Postal Code', 'Message', 'Categories', 'images',
#        'website', 'phone', 'email', 'Click Action', 'Redirect URL',
#        'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
#Create a new Field landmark in CSV 
stats['Landmark'] = stats.City + stats.State

# %%
stats
# Out:
#     Unnamed: 0                                     Title  \
# 0          NaN                                Amber Fort
# 1          NaN                           Mehrangarh Fort
# 2          NaN                   National Gallery of Art
# 3          NaN                        Hill Palace Museum
# 4          NaN                              Kirti Mandir
# 5          NaN                      Nehru Science Centre
# 6          NaN                      Raman Science Centre
# 7          NaN                           Red Fort, Delhi
# 8          NaN                             Mysore Palace
# 9          NaN                          Agra Fort, Agra.
# 10         NaN                             Junagadh Fort
# 11         NaN                                   Gulmarg
# 12         NaN                                  Pahalgam
# 13         NaN                                  Sonamarg
# 14         NaN                             Varkala Beach
# ...

# %%
remove18 = stats.drop('Unnamed: 18',1)

# %%
remove18
# Out:
#     Unnamed: 0                                     Title  \
# 0          NaN                                Amber Fort
# 1          NaN                           Mehrangarh Fort
# 2          NaN                   National Gallery of Art
# 3          NaN                        Hill Palace Museum
# 4          NaN                              Kirti Mandir
# 5          NaN                      Nehru Science Centre
# 6          NaN                      Raman Science Centre
# 7          NaN                           Red Fort, Delhi
# 8          NaN                             Mysore Palace
# 9          NaN                          Agra Fort, Agra.
# 10         NaN                             Junagadh Fort
# 11         NaN                                   Gulmarg
# 12         NaN                                  Pahalgam
# 13         NaN                                  Sonamarg
# 14         NaN                             Varkala Beach
# ...

# %%
remove0 = stats.drop('Unnamed: 0',1)

# %%
remove0
# Out:
#                                        Title  \
# 0                                 Amber Fort
# 1                            Mehrangarh Fort
# 2                    National Gallery of Art
# 3                         Hill Palace Museum
# 4                               Kirti Mandir
# 5                       Nehru Science Centre
# 6                       Raman Science Centre
# 7                            Red Fort, Delhi
# 8                              Mysore Palace
# 9                           Agra Fort, Agra.
# 10                             Junagadh Fort
# 11                                   Gulmarg
# 12                                  Pahalgam
# 13                                  Sonamarg
# 14                             Varkala Beach
# 15                                    Shimla
# 16                                   Kasauli
# 17                                   Lonavla
# 18                                  Shillong
# 19                    Gokarna Beach, Gokarna
# ...

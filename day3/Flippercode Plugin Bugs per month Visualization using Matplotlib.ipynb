# %%
#Bugs Received on Each month on Wordpress Plugins

import numpy as np

Month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sept','Oct','Nov','Dec']
MDict = {'Jan': 0, 'Feb':1, 'Mar':2, 'Apr':3,'May':4,'Jun':5, 'Jul':6,'Aug':7,'Sept':8,'Oct':9,'Nov':10,'Dec':11}

Plugin = ['GoogleMapsPro','UserAvatar','StoreLocator','Ecards','ReminderPro','CF7Extensions','DeliveryArea','UpdatesPro','ImageHover','SecurityQuestions','BookingPopup','GDPR']
PDict = {'GoogleMapsPro':0,'UserAvatar':1,'StoreLocator':2,'Ecards':3,'ReminderPro':4,'CF7Extensions':5,'DeliveryArea':6,'UpdatesPro':7,'ImageHover':8,'SecurityQuestions':9,'BookingPopup':10,'GDPR':11}



#Bugs

GoogleMapsPro_Bugs = [2,1,5,3,4,2,0,1,3,2,0,0]
UserAvatar_Bugs = [2,4,2,0,0,1,3,1,3,0,1,7]
StoreLocator_Bugs = [1,3,4,1,0,0,9,2,4,3,1,0]
Ecards_Bugs = [0,1,2,3,4,5,6,7,8,3,2,5,1]
ReminderPro_Bugs = [3,1,3,0,1,7,8,5,4,1,0,0]
CF7Extensions_Bugs = [0,1,3,2,0,4,3,8,6,4,0,0]
DeliveryArea_Bugs = [1,0,0,9,2,4,3,1,0,4,6,2]
UpdatesPro_Bugs = [0,0,9,2,4,3,1,0,4,2,3,4]
ImageHover_Bugs = [1,3,0,1,7,5,4,2,3,4,1,9]
SecurityQuestions_Bugs = [5,6,7,8,3,2,5,1,4,6,7,1]
BookingPopup_Bugs = [0,0,9,2,4,3,1,0,8,6,4,0]
GDPR_Bugs = [2,0,4,3,8,6,4,0,0,1,3,1]

Bugs = np.array([GoogleMapsPro_Bugs,UserAvatar_Bugs,StoreLocator_Bugs,Ecards_Bugs,ReminderPro_Bugs,CF7Extensions_Bugs,DeliveryArea_Bugs,UpdatesPro_Bugs,ImageHover_Bugs,SecurityQuestions_Bugs,BookingPopup_Bugs,GDPR_Bugs])

# %%
import matplotlib.pyplot as plt

plt.plot( Bugs[0],  c="Black",      ls="--", marker ="s", ms="10", label = Month[0])
plt.plot( Bugs[1],  c="Green",      ls="--", marker ="P", ms="10", label = Month[1])
plt.plot( Bugs[2],  c="Red",        ls="--", marker ="o", ms="10", label = Month[2])
plt.plot( Bugs[3],  c="Brown",      ls="--", marker ="v", ms="10", label = Month[3])
plt.plot( Bugs[4],  c="Blue",       ls="--", marker =".", ms="10", label = Month[4])
plt.plot( Bugs[5],  c="Yellow",     ls="--", marker ="d", ms="10", label = Month[5])
plt.plot( Bugs[6],  c="Gray",       ls="--", marker ="D", ms="10", label = Month[6])
plt.plot( Bugs[7],  c="Magenta",    ls="--", marker ="p", ms="10", label = Month[7])
plt.plot( Bugs[8],  c="cyan",       ls="--", marker ="*", ms="10", label = Month[8])
plt.plot( Bugs[9],  c="skyblue",    ls="--", marker ="8", ms="10", label = Month[9])
plt.plot( Bugs[10], c="black",      ls="-",  marker =".", ms="10", label = Month[10])
plt.plot( Bugs[11], c="red",        ls="-",  marker ="h", ms="10", label = Month[10])

plt.rcParams['figure.figsize'] =10,12 # for size of the graph
plt.legend( Plugin, loc='upper left' , bbox_to_anchor=(1,1))
plt.xticks(list(range(0,12)),Month)
plt.show()

# %%
#Number of bugs received each month in Google Maps Plugin
Bugs[0]
# Out:
# [2, 1, 5, 3, 4, 2, 0, 1, 3, 2, 0, 0]

# %%
#Number of bugs received in December  Google Maps Plugin
Bugs[PDict["GoogleMapsPro"]][MDict["Dec"]]
# Out:
# 0

# %%
#Number of bugs received in January  Google Maps Plugin
Bugs[PDict["GoogleMapsPro"]][MDict["Jan"]]
# Out:
# 2

# %%
#To get details of Bug received on each month, please insert the Plugin name and Month
#Number of bugs received in December on User Avatar
Bugs[PDict["UserAvatar"]][MDict["Jul"]]
# Out:
# 3
